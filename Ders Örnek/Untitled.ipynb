# %%
import pandas as pd

# %%
sayilar=pd.Series([0,1,5,6,7,8,90,104,9,106,250,46,19],name="Sayilar")
sayilar
# Out:
# 0       0
# 1       1
# 2       5
# 3       6
# 4       7
# 5       8
# 6      90
# 7     104
# 8       9
# 9     106
# 10    250
# 11     46
# 12     19
# Name: Sayilar, dtype: int64

# %%
df=pd.read_csv('apple.csv',index_col="Date",parse_dates=True)

# %%
df=df.sort_index()

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 111 entries, 2005-01-03 to 2014-03-03
# Data columns (total 6 columns):
# Open         111 non-null float64
# High         111 non-null float64
# Low          111 non-null float64
# Close        111 non-null float64
# Volume       111 non-null int64
# Adj Close    111 non-null float64
# dtypes: float64(5), int64(1)
# memory usage: 6.1 KB
# None

# %%
df.loc['2013','Close'].mean()
# Out:
# 473.73999999999995

# %%
print(df.loc['2010-Jan':'2014-Jan','Close'].mean())
# Out:
# 423.0363265306122

# %%
import matplotlib.pyplot as plt

# %%
data_frame=df.loc['2010-Jan':'2014-Jan',['Close']]
data_frame.plot()
plt.show()

# %%
data_frame=df.loc['2010-Jan':'2014-Jan',['Volume']]
data_frame.plot()
plt.show()

# %%
df=pd.read_csv('Salaries.csv')

# %%
print(df.head())
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
print(df.head(5))
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
print(df.tail(5))
# Out:
#          rank discipline  phd  service     sex  salary
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
print(df.tail(-1))
# Out:
#          rank discipline  phd  service     sex  salary
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [77 rows x 6 columns]

# %%
print(df.dtypes)
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %%
print(df.columns)
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
print(df.axes)
# Out:
# [RangeIndex(start=0, stop=78, step=1), Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')]

# %%
print(df.size)
# Out:
# 468

# %%
df.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
df.max()
# Out:
# rank            Prof
# discipline         B
# phd               56
# service           51
# sex             Male
# salary        186960
# dtype: object

# %%
df.min()
# Out:
# rank          AssocProf
# discipline            A
# phd                   1
# service               0
# sex              Female
# salary            57800
# dtype: object

# %%
df.mean()
# Out:
# phd            19.705128
# service        15.051282
# salary     108023.782051
# dtype: float64

# %%
df.median()
# Out:
# phd            18.5
# service        14.5
# salary     104671.0
# dtype: float64

# %%
df.std()
# Out:
# phd           12.498425
# service       12.139768
# salary     28293.661022
# dtype: float64

# %%
df_rank=df.groupby(['rank'])
print(df_rank.mean())
# Out:
#                  phd    service         salary
# rank
# AssocProf  15.076923  11.307692   91786.230769
# AsstProf    5.052632   2.210526   81362.789474
# Prof       27.065217  21.413043  123624.804348

# %%
flights=pd.read_csv('flights.csv')

# %%
print(flights.size)
# Out:
# 2572064

# %%
flights[flights.isnull().any(axis=1)].head()
# Out:
#      year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 330  2013      1    1    1807.0       29.0    2251.0        NaN      UA
# 403  2013      1    1       NaN        NaN       NaN        NaN      AA
# 404  2013      1    1       NaN        NaN       NaN        NaN      AA
# 855  2013      1    2    2145.0       16.0       NaN        NaN      UA
# 858  2013      1    2       NaN        NaN       NaN        NaN      AA
#
#     tailnum  flight origin dest  air_time  distance  hour  minute
# 330  N31412    1228    EWR  SAN       NaN      2425  18.0     7.0
# 403  N3EHAA     791    LGA  DFW       NaN      1389   NaN     NaN
# 404  N3EVAA    1925    LGA  MIA       NaN      1096   NaN     NaN
# 855  N12221    1299    EWR  RSW       NaN      1068  21.0    45.0
# 858     NaN     133    JFK  LAX       NaN      2475   NaN     NaN
